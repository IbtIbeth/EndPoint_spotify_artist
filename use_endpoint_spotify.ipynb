# %% [markdown]
# # Endpoint de Spotify desde un script

# %%
import requests
import base64
import json
from secrets import *
import pandas as pd

# %%
url = "https://accounts.spotify.com/api/token"
headers = {}
data = {}

# %%
clientID = ''
clientSecret = ''

# %%
message = f"{clientID}:{clientSecret}"
messageBytes = message.encode('ascii')
base64Bytes = base64.b64encode(messageBytes)
base64Message = base64Bytes.decode('ascii')

# %%
url = "https://accounts.spotify.com/api/token"
headers = {}
data = {}

message = f"{clientID}:{clientSecret}"
messageBytes = message.encode('ascii')
base64Bytes = base64.b64encode(messageBytes)
base64Message = base64Bytes.decode('ascii')

headers['Authorization'] = f"Basic {base64Message}"
data['grant_type'] = "client_credentials"

r = requests.post(url, headers=headers, data=data)
token = r.json()['access_token']

headers = {"Authorization": "Bearer " + token}

# %%
artistUrl = "https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR/top-tracks?market=Mx"
res = requests.get(url=artistUrl, headers=headers)
data = json.dumps(res.json())
dicc = json.loads(data)

# %%
df = pd.DataFrame(dicc['tracks'])

# %% [markdown]
# ### Muestra las 10 canciones mas populares de Ariana Grande en México, incluyendo datos importantes como el album, polpularidad, minutos que ha sido reproducida etc.

# %%
df
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'single', 'artists': [{'externa...
# 4  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'single', 'artists': [{'externa...
# 8  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# ...
